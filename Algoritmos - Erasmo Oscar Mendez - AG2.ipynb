# %% [markdown]
# ## Actividad Guiada 2
# ## Erasmo Oscar Mendez Chavez
#
# ## GitHub: https://github.com/erasmomendez/03MIARAlgortimos.git

# %% [markdown]
# PREPARA EL ENTORNO

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import random

# %% [markdown]
# FUNCION A MINIMIZAR: PARABOLOIDE

# %%
f  = lambda X:     X[0]**2 + X[1]**2
df = lambda X:  [2*X[0] , 2*X[1]]

# %% [markdown]
# PREPARA LOS DATOS PARA EL GRAFICO

# %%
# Prepara los datos para dibujar mapa de niveles de Z

resolucion = 100
rango = 2.5
X = np.linspace(-rango, rango, resolucion)
Y = np.linspace(-rango, rango, resolucion)
Z = np.zeros((resolucion, resolucion))

for ix,x in enumerate(X):
    for iy,y in enumerate(Y):
        Z[iy, ix] = f([x,y])

#Pinta el mapa de niveles de Z
contour = plt.contourf(X, Y, Z, resolucion)
char = plt.colorbar(contour)

# Generamos un punto aleatorio

P = [random.uniform(-rango,rango), random.uniform(-rango,rango )]
plt.plot(P[0],P[1],"o",c="red")

# Tasa de aprendizaje
TA = .05

# Iteraciones

for _ in range(500):
  grad = df(P)
  # Pt+1 = Pt - &t*Grad(Pt)
  P[0],P[1] = P[0] - TA*grad[0] , P[1] - TA*grad[1]
  plt.plot(P[0],P[1],"o",c="red")

plt.plot(P[0],P[1],"o",c='white')
plt.show()
print("Solucion: ", P , f(P))
# Out:
# Solucion:  [-1.322578862875519e-23, 2.83321957339877e-23] 9.77634799961501e-46
